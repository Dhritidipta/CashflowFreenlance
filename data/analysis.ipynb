# %%
import pandas as pd

# %%
from fetch import get_all_companies_df, get_company_df,get_exchange_rates_df,get_all_sepa_transactions_df,get_all_swift_transactions_df

# %%
display(get_all_companies_df())
# Out:
#    id                            ibans                         name  \
# 0   2       ['GB51SJEV83747591864014']             Poirier S.A.R.L.
# 1   3       ['DE14065609541598144038']                 Bourdon S.A.
# 2   4       ['DE77193919112673928344']                       Samson
# 3   5           ['NL28SZUK8962850954']                       Trespa
# 4   6  ['FR8396285095416080726847111']             Remmers & Gruijl
# 5   7       ['DE19272666529915228004']  Houghton, Murray and Thomas
# 6   8       ['GB31YQDI40383542281132']               Leblanc S.A.S.
# 7   9           ['NL06DCVI2439040656']          Guillon Lesage S.A.
# 8  10           ['NL76AWSK4159814403']               Hayes and Sons
# 9  11       ['DE09167966841644539374']             Wagenvoort Groep
#
#                                              address
# 0       66 Gallagher river\nWest Jacobburgh\nB0E 5TY
# 1    62, boulevard de Imbert\n52593 Hebert-les-Bains
# 2                 Nisapad 85\n2112 OC\nKootstertille
# ...
